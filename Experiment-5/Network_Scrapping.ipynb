# %%
from snscrape.modules import  twitter

# %%
twitter.TwitterProfileScraper("zomato").entity
# Out:
# User(username='zomato', id=23283603, displayname='zomato', rawDescription='sending good vibes to everyone reading this 🤗 for any support, you can reach out to @zomatocare', renderedDescription='sending good vibes to everyone reading this 🤗 for any support, you can reach out to @zomatocare', descriptionLinks=[], verified=True, created=datetime.datetime(2009, 3, 8, 6, 18, 24, tzinfo=datetime.timezone.utc), followersCount=1571031, friendsCount=7, statusesCount=13145, favouritesCount=4637, listedCount=621, mediaCount=722, location='India 🇮🇳', protected=False, link=None, profileImageUrl='https://pbs.twimg.com/profile_images/1100268333352525826/IkyIXuZ4_normal.png', profileBannerUrl='https://pbs.twimg.com/profile_banners/23283603/1673515223', label=None)

# %%
import pandas

# %%
data= pandas.read_csv("./Nodes.csv")

# %%
data
# Out:
#                              profileUrl       screenName               userId  \
# 0        https://twitter.com/deepigoyal       deepigoyal             72481380
# 1         https://twitter.com/arcomedys        arcomedys   873644383165435906
# 2    https://twitter.com/Sahilarioussss   Sahilarioussss  1176953263184404483
# 3     https://twitter.com/MehulFanawala    MehulFanawala            114203360
# 4          https://twitter.com/albinder         albinder             21843174
# 5     https://twitter.com/Social_Samosa    Social_Samosa            390602999
# 6       https://twitter.com/Chai_n_love      Chai_n_love  1214507121909223425
# 7         https://twitter.com/whysaloni        whysaloni   862339384678518785
# 8     https://twitter.com/highonsaudade    highonsaudade  1397629124173205505
# 9        https://twitter.com/zomatocare       zomatocare   988362975617601536
# 10    https://twitter.com/Awwwchallllll    Awwwchallllll   974261491636387840
# ...

# %%
Nodes=data[['userId','screenName','name','friendsCount','followersCount']]

# %%
Nodes
# Out:
#                  userId       screenName                   name  friendsCount  \
# 0              72481380       deepigoyal        Deepinder Goyal            11
# 1    873644383165435906        arcomedys                 Savage           657
# 2   1176953263184404483   Sahilarioussss         Sahilarioussss           996
# 3             114203360    MehulFanawala         Mehul Fanawala          5218
# 4              21843174         albinder       Albinder Dhindsa           893
# 5             390602999    Social_Samosa          Social Samosa            93
# 6   1214507121909223425      Chai_n_love           Chai Kadak ☕          3429
# 7    862339384678518785        whysaloni          Saloni Mittal           762
# 8   1397629124173205505    highonsaudade          Shirin Sharma          1029
# 9    988362975617601536       zomatocare            zomato care            15
# 10   974261491636387840    Awwwchallllll               Aachal 🌠           511
# ...

# %%
Nodes.columns=['Id','screenName','name','friendsCount','followersCount']

# %%
Nodes
# Out:
#                  userId       screenName                   name  friendsCount  \
# 0              72481380       deepigoyal        Deepinder Goyal            11
# 1    873644383165435906        arcomedys                 Savage           657
# 2   1176953263184404483   Sahilarioussss         Sahilarioussss           996
# 3             114203360    MehulFanawala         Mehul Fanawala          5218
# 4              21843174         albinder       Albinder Dhindsa           893
# 5             390602999    Social_Samosa          Social Samosa            93
# 6   1214507121909223425      Chai_n_love           Chai Kadak ☕          3429
# 7    862339384678518785        whysaloni          Saloni Mittal           762
# 8   1397629124173205505    highonsaudade          Shirin Sharma          1029
# 9    988362975617601536       zomatocare            zomato care            15
# 10   974261491636387840    Awwwchallllll               Aachal 🌠           511
# ...

# %%
Nodes.to_csv("./Followers/Nodes.csv",index=False)

# %%
data3 = pandas.read_csv("./Edges.csv")

# %%
data3
# Out:
#                               profileUrl       screenName  \
# 0           https://twitter.com/kunalb11         kunalb11
# 1     https://twitter.com/Ashneer_Grover   Ashneer_Grover
# 2         https://twitter.com/Nithin0dha       Nithin0dha
# 3       https://twitter.com/AnupamMittal     AnupamMittal
# 4              https://twitter.com/bhash            bhash
# ..                                   ...              ...
# 995      https://twitter.com/jamaalgota_      jamaalgota_
# 996     https://twitter.com/bh_subbaraju     bh_subbaraju
# 997    https://twitter.com/RaviM58607183    RaviM58607183
# 998           https://twitter.com/jdiitk           jdiitk
# 999  https://twitter.com/InderPr21941665  InderPr21941665
#
#                   userId              name  \
# 0               32332988        Kunal Shah
# 1    1459126464931008520    Ashneer Grover
# 2             1660202983     Nithin Kamath
# 3               22596514     Anupam Mittal
# 4               16489912  Bhavish Aggarwal
# ...

# %%
data3['Source']=data3['query'].apply(lambda x: x.split("/")[-1])

# %%
data3=data3[['userId','screenName','name','friendsCount','followersCount','Source']]

# %%
data3.dropna(inplace=True)
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_11608\3651136420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.dropna(inplace=True)

# %%
data3
# Out:
#                   userId       screenName              name  friendsCount  \
# 0               32332988         kunalb11        Kunal Shah          1319
# 1    1459126464931008520   Ashneer_Grover    Ashneer Grover            18
# 2             1660202983       Nithin0dha     Nithin Kamath           151
# 3               22596514     AnupamMittal     Anupam Mittal           628
# 4               16489912            bhash  Bhavish Aggarwal           503
# ..                   ...              ...               ...           ...
# 995  1389327875996717057      jamaalgota_  chandu ka chacha            35
# 996   714831085721493504     bh_subbaraju      Subbaraju BH           249
# 997  1425133308669689860    RaviM58607183        Ravi kiran            96
# 998            102091475           jdiitk      Jaideep Bedi            48
# 999  1572245173412982785  InderPr21941665     Inder Prakash            99
#
#      followersCount      Source
# 0            770664  deepigoyal
# ...

# %%
new_data=data3.drop_duplicates(subset=['userId'])

# %%
new_data
# Out:
#                   userId       screenName              name  friendsCount  \
# 0               32332988         kunalb11        Kunal Shah          1319
# 1    1459126464931008520   Ashneer_Grover    Ashneer Grover            18
# 2             1660202983       Nithin0dha     Nithin Kamath           151
# 3               22596514     AnupamMittal     Anupam Mittal           628
# 4               16489912            bhash  Bhavish Aggarwal           503
# ..                   ...              ...               ...           ...
# 995  1389327875996717057      jamaalgota_  chandu ka chacha            35
# 996   714831085721493504     bh_subbaraju      Subbaraju BH           249
# 997  1425133308669689860    RaviM58607183        Ravi kiran            96
# 998            102091475           jdiitk      Jaideep Bedi            48
# 999  1572245173412982785  InderPr21941665     Inder Prakash            99
#
#      followersCount
# 0            770664
# 1            271756
# ...

# %%
len(data3['Source'].unique())
# Out:
# 5

# %%
new_data=new_data.drop(['Source'],axis=1)

# %%
new_data
# Out:
#                   userId       screenName              name  friendsCount  \
# 0               32332988         kunalb11        Kunal Shah          1319
# 1    1459126464931008520   Ashneer_Grover    Ashneer Grover            18
# 2             1660202983       Nithin0dha     Nithin Kamath           151
# 3               22596514     AnupamMittal     Anupam Mittal           628
# 4               16489912            bhash  Bhavish Aggarwal           503
# ..                   ...              ...               ...           ...
# 995  1389327875996717057      jamaalgota_  chandu ka chacha            35
# 996   714831085721493504     bh_subbaraju      Subbaraju BH           249
# 997  1425133308669689860    RaviM58607183        Ravi kiran            96
# 998            102091475           jdiitk      Jaideep Bedi            48
# 999  1572245173412982785  InderPr21941665     Inder Prakash            99
#
#      followersCount
# 0            770664
# 1            271756
# ...

# %%
Total_Nodes
# Out:
#                   userId       screenName              name  friendsCount  \
# 0               72481380       deepigoyal   Deepinder Goyal            11
# 1     873644383165435906        arcomedys            Savage           657
# 2    1176953263184404483   Sahilarioussss    Sahilarioussss           996
# 3              114203360    MehulFanawala    Mehul Fanawala          5218
# 4               21843174         albinder  Albinder Dhindsa           893
# ..                   ...              ...               ...           ...
# 995  1389327875996717057      jamaalgota_  chandu ka chacha            35
# 996   714831085721493504     bh_subbaraju      Subbaraju BH           249
# 997  1425133308669689860    RaviM58607183        Ravi kiran            96
# 998            102091475           jdiitk      Jaideep Bedi            48
# 999  1572245173412982785  InderPr21941665     Inder Prakash            99
#
#      followersCount
# 0            582271
# 1             32415
# ...

# %%
Total_Nodes=pandas.concat([Nodes,new_data])

# %%
Total_Nodes.columns=['Id','Label','name','friendsCount','followersCount']

# %%
Total_Nodes
# Out:
#                       Id            Label              name  friendsCount  \
# 0               72481380       deepigoyal   Deepinder Goyal            11
# 1     873644383165435906        arcomedys            Savage           657
# 2    1176953263184404483   Sahilarioussss    Sahilarioussss           996
# 3              114203360    MehulFanawala    Mehul Fanawala          5218
# 4               21843174         albinder  Albinder Dhindsa           893
# ..                   ...              ...               ...           ...
# 995  1389327875996717057      jamaalgota_  chandu ka chacha            35
# 996   714831085721493504     bh_subbaraju      Subbaraju BH           249
# 997  1425133308669689860    RaviM58607183        Ravi kiran            96
# 998            102091475           jdiitk      Jaideep Bedi            48
# 999  1572245173412982785  InderPr21941665     Inder Prakash            99
#
#      followersCount
# 0            582271
# 1             32415
# ...

# %%
himalayadata=[{
    "Id":23283603,
    "Label":"zomato",
    "name":"zomato",
    "friendsCount":7,
    "followersCount":1571031
}]

# %%
pandas.DataFrame(himalayadata)
# Out:
#          Id   Label    name  friendsCount  followersCount
# 0  23283603  zomato  zomato             7         1571031

# %%
Total_Nodes=pandas.concat([pandas.DataFrame(himalayadata),Total_Nodes],ignore_index=True)

# %%
Total_Nodes
# Out:
#                       Id            Label              name  friendsCount  \
# 0               23283603           zomato            zomato             7
# 1               23283603           zomato            zomato             7
# 2               72481380       deepigoyal   Deepinder Goyal            11
# 3     873644383165435906        arcomedys            Savage           657
# 4    1176953263184404483   Sahilarioussss    Sahilarioussss           996
# ..                   ...              ...               ...           ...
# 960  1389327875996717057      jamaalgota_  chandu ka chacha            35
# 961   714831085721493504     bh_subbaraju      Subbaraju BH           249
# 962  1425133308669689860    RaviM58607183        Ravi kiran            96
# 963            102091475           jdiitk      Jaideep Bedi            48
# 964  1572245173412982785  InderPr21941665     Inder Prakash            99
#
#      followersCount
# 0           1571031
# 1           1571031
# ...

# %%
Total_Nodes=Total_Nodes.drop_duplicates(subset=['Id'])

# %%
Total_Nodes['Id']=Total_Nodes['Id'].apply(lambda x:float(x))
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_11608\4120943519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Total_Nodes['Id']=Total_Nodes['Id'].apply(lambda x:float(x))

# %%
Total_Nodes.to_csv("./Total_Nodes.csv",index=False)

# %%
Total_Nodes
# Out:
#                Id            Label              name  friendsCount  \
# 0    2.328360e+07           zomato            zomato             7
# 2    7.248138e+07       deepigoyal   Deepinder Goyal            11
# 3    8.736444e+17        arcomedys            Savage           657
# 4    1.176953e+18   Sahilarioussss    Sahilarioussss           996
# 5    1.142034e+08    MehulFanawala    Mehul Fanawala          5218
# ..            ...              ...               ...           ...
# 960  1.389328e+18      jamaalgota_  chandu ka chacha            35
# 961  7.148311e+17     bh_subbaraju      Subbaraju BH           249
# 962  1.425133e+18    RaviM58607183        Ravi kiran            96
# 963  1.020915e+08           jdiitk      Jaideep Bedi            48
# 964  1.572245e+18  InderPr21941665     Inder Prakash            99
#
#      followersCount
# 0           1571031
# 2            582271
# 3             32415
# 4             27552
# 5             27527
# ..              ...
# ...

# %%
Nodes['Source']=23283603
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_11608\4098193657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nodes['Source']=23283603

# %%
Nodes
# Out:
#                  userId       screenName                   name  friendsCount  \
# 0              72481380       deepigoyal        Deepinder Goyal            11
# 1    873644383165435906        arcomedys                 Savage           657
# 2   1176953263184404483   Sahilarioussss         Sahilarioussss           996
# 3             114203360    MehulFanawala         Mehul Fanawala          5218
# 4              21843174         albinder       Albinder Dhindsa           893
# 5             390602999    Social_Samosa          Social Samosa            93
# 6   1214507121909223425      Chai_n_love           Chai Kadak ☕          3429
# 7    862339384678518785        whysaloni          Saloni Mittal           762
# 8   1397629124173205505    highonsaudade          Shirin Sharma          1029
# 9    988362975617601536       zomatocare            zomato care            15
# 10   974261491636387840    Awwwchallllll               Aachal 🌠           511
# ...

# %%
Total_Edges=Nodes[['Source',"userId"]]

# %%
Total_Edges.columns=['Source',"Target"]

# %%
Total_Edges['Type']="Directed"
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_11608\2225936721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Total_Edges['Type']="Directed"

# %%
Total_Edges
# Out:
#       Source               Target      Type
# 0   23283603             72481380  Directed
# 1   23283603   873644383165435906  Directed
# 2   23283603  1176953263184404483  Directed
# 3   23283603            114203360  Directed
# 4   23283603             21843174  Directed
# 5   23283603            390602999  Directed
# 6   23283603  1214507121909223425  Directed
# 7   23283603   862339384678518785  Directed
# 8   23283603  1397629124173205505  Directed
# 9   23283603   988362975617601536  Directed
# 10  23283603   974261491636387840  Directed
# 11  23283603  1298868025697775616  Directed
# 12  23283603            193260163  Directed
# 13  23283603   838879686797090820  Directed
# 14  23283603           1183634323  Directed
# 15  23283603            292159076  Directed
# 16  23283603   866959946927177728  Directed
# 17  23283603            481968108  Directed
# 18  23283603  1244851747375296513  Directed
# 19  23283603             15170758  Directed
# ...

# %%
Nodes.columns=['source_id', 'source_name', 'name', 'friendsCount', 'followersCount','Source']

# %%
Nodes
# Out:
#               source_id      source_name                   name  friendsCount  \
# 0              72481380       deepigoyal        Deepinder Goyal            11
# 1    873644383165435906        arcomedys                 Savage           657
# 2   1176953263184404483   Sahilarioussss         Sahilarioussss           996
# 3             114203360    MehulFanawala         Mehul Fanawala          5218
# 4              21843174         albinder       Albinder Dhindsa           893
# 5             390602999    Social_Samosa          Social Samosa            93
# 6   1214507121909223425      Chai_n_love           Chai Kadak ☕          3429
# 7    862339384678518785        whysaloni          Saloni Mittal           762
# 8   1397629124173205505    highonsaudade          Shirin Sharma          1029
# 9    988362975617601536       zomatocare            zomato care            15
# 10   974261491636387840    Awwwchallllll               Aachal 🌠           511
# ...

# %%
data3.rename({"Source":"source_name"},inplace=True,axis=1)
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_11608\2399550445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.rename({"Source":"source_name"},inplace=True,axis=1)

# %%
data3
# Out:
#                   userId       screenName              name  friendsCount  \
# 0               32332988         kunalb11        Kunal Shah          1319
# 1    1459126464931008520   Ashneer_Grover    Ashneer Grover            18
# 2             1660202983       Nithin0dha     Nithin Kamath           151
# 3               22596514     AnupamMittal     Anupam Mittal           628
# 4               16489912            bhash  Bhavish Aggarwal           503
# ..                   ...              ...               ...           ...
# 995  1389327875996717057      jamaalgota_  chandu ka chacha            35
# 996   714831085721493504     bh_subbaraju      Subbaraju BH           249
# 997  1425133308669689860    RaviM58607183        Ravi kiran            96
# 998            102091475           jdiitk      Jaideep Bedi            48
# 999  1572245173412982785  InderPr21941665     Inder Prakash            99
#
#      followersCount source_name
# 0            770664  deepigoyal
# ...

# %%
temp=data3.merge(Nodes[['source_name','source_id']],on="source_name")

# %%
temp
# Out:
#                   userId       screenName              name  friendsCount  \
# 0               32332988         kunalb11        Kunal Shah          1319
# 1    1459126464931008520   Ashneer_Grover    Ashneer Grover            18
# 2             1660202983       Nithin0dha     Nithin Kamath           151
# 3               22596514     AnupamMittal     Anupam Mittal           628
# 4               16489912            bhash  Bhavish Aggarwal           503
# ..                   ...              ...               ...           ...
# 995  1389327875996717057      jamaalgota_  chandu ka chacha            35
# 996   714831085721493504     bh_subbaraju      Subbaraju BH           249
# 997  1425133308669689860    RaviM58607183        Ravi kiran            96
# 998            102091475           jdiitk      Jaideep Bedi            48
# 999  1572245173412982785  InderPr21941665     Inder Prakash            99
#
#      followersCount source_name  source_id
# ...

# %%
temp=temp[['source_id',"userId"]]

# %%
temp.columns=['Source',"Target"]

# %%
temp['Type']="Directed"
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_11608\3564052516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Type']="Directed"

# %%
temp.drop_duplicates()
# Out:
#        Source               Target      Type
# 0    72481380             32332988  Directed
# 1    72481380  1459126464931008520  Directed
# 2    72481380           1660202983  Directed
# 3    72481380             22596514  Directed
# 4    72481380             16489912  Directed
# ..        ...                  ...       ...
# 995  21843174  1389327875996717057  Directed
# 996  21843174   714831085721493504  Directed
# 997  21843174  1425133308669689860  Directed
# 998  21843174            102091475  Directed
# 999  21843174  1572245173412982785  Directed
#
# [1000 rows x 3 columns]

# %%
Total_Edges=pandas.concat([Total_Edges,temp])

# %%
Total_Edges.to_csv("./Total_Edges.csv",index=False)

# %%
Total_Edges
# Out:
#        Source               Target      Type
# 0    23283603             72481380  Directed
# 1    23283603   873644383165435906  Directed
# 2    23283603  1176953263184404483  Directed
# 3    23283603            114203360  Directed
# 4    23283603             21843174  Directed
# ..        ...                  ...       ...
# 995  21843174  1389327875996717057  Directed
# 996  21843174   714831085721493504  Directed
# 997  21843174  1425133308669689860  Directed
# 998  21843174            102091475  Directed
# 999  21843174  1572245173412982785  Directed
#
# [1025 rows x 3 columns]

# %%
len(data3['screenName'].unique())
# Out:
# 938
