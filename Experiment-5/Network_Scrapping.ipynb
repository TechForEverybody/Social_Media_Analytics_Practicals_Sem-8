# %%
from snscrape.modules import  twitter

# %%
limit=10
tweets=[]
counter=0
for tweet in twitter.TwitterProfileScraper("HimalayaIndia").entity():
    if counter>=limit:
        break
    counter+=1
    print(tweet.)
# Out:
# https://twitter.com/HimalayaIndia/status/1628651174760181760
# https://twitter.com/HimalayaIndia/status/1632274578599997440
# https://twitter.com/HimalayaIndia/status/1628656634892550148
# https://twitter.com/HimalayaIndia/status/1628647065571201029
# https://twitter.com/HimalayaIndia/status/1625480333704695808
# https://twitter.com/HimalayaIndia/status/1618197659369488385
# https://twitter.com/HimalayaIndia/status/1617375889024749568
# https://twitter.com/HimalayaIndia/status/1615291322046504961
# https://twitter.com/HimalayaIndia/status/1613847830019571712
# https://twitter.com/HimalayaIndia/status/1613762923679330305

# %%
twitter.TwitterProfileScraper("HimalayaIndia").entity
# Out:
# User(username='HimalayaIndia', id=423190436, displayname='Himalaya Wellness Company', rawDescription='A contemporary Ayurveda brand that offers head-to-heel range of wellness products enriched with the goodness of herbs. Made in India | Since 1930', renderedDescription='A contemporary Ayurveda brand that offers head-to-heel range of wellness products enriched with the goodness of herbs. Made in India | Since 1930', descriptionLinks=[], verified=False, created=datetime.datetime(2011, 11, 28, 5, 58, 59, tzinfo=datetime.timezone.utc), followersCount=15719, friendsCount=53, statusesCount=5165, favouritesCount=3694, listedCount=56, mediaCount=2115, location='Bengaluru, India', protected=False, link=TextLink(text='himalayawellness.in', url='https://himalayawellness.in/', tcourl='https://t.co/Bkhq6DyqWs', indices=(0, 23)), profileImageUrl='https://pbs.twimg.com/profile_images/1562034101447962624/GhDp7J9T_normal.jpg', profileBannerUrl='https://pbs.twimg.com/profile_banners/423190436/16777484
# ...

# %%
import pandas

# %%
data= pandas.read_csv("./Followers/result.csv")

# %%
data
# Out:
#                              profileUrl       screenName               userId  \
# 0     https://twitter.com/ParvinKamble6    ParvinKamble6  1605392339488210945
# 1          https://twitter.com/devanlli         devanlli  1591975778266189825
# 2     https://twitter.com/PuneetNigam11    PuneetNigam11  1120173746369646592
# 3         https://twitter.com/palta_dr_        palta_dr_  1590063878511419393
# 4        https://twitter.com/KashniyalM       KashniyalM   809219187386306560
# ..                                  ...              ...                  ...
# 95  https://twitter.com/Shreyasgowda301  Shreyasgowda301  1144086798844358656
# 96      https://twitter.com/diosleayuda      diosleayuda  1582624744444030977
# 97    https://twitter.com/kamlamahendra    kamlamahendra  1022740677757554689
# 98         https://twitter.com/Bertinrm         Bertinrm            771733183
# 99       https://twitter.com/HenryTana3       HenryTana3  1618279715587899393
#
# ...

# %%
Nodes=data[['userId','screenName','name','friendsCount','followersCount']]

# %%
Nodes.columns=['Id','screenName','name','friendsCount','followersCount']

# %%
Nodes
# Out:
#                  userId       screenName                    name  \
# 0   1605392339488210945    ParvinKamble6           Parvin Kamble
# 1   1591975778266189825         devanlli        purnima devanlli
# 2   1120173746369646592    PuneetNigam11            Puneet Nigam
# 3   1590063878511419393        palta_dr_     Anuradha palta ,PhD
# 4    809219187386306560       KashniyalM        Kashniyal Manish
# ..                  ...              ...                     ...
# 95  1144086798844358656  Shreyasgowda301         Shreyasgowda@30
# 96  1582624744444030977      diosleayuda                      さに
# 97  1022740677757554689    kamlamahendra  mahendra kumar bhaskar
# 98            771733183         Bertinrm                  Bertin
# 99  1618279715587899393       HenryTana3              Henry Tana
#
#     friendsCount  followersCount
# 0              3               0
# 1             24               1
# 2             77               4
# 3            223              57
# ...

# %%
Nodes.to_csv("./Followers/Nodes.csv",index=False)

# %%
data3 = pandas.read_csv("./Followers/result.csv")

# %%
data3['Source']=data3['query'].apply(lambda x: x.split("/")[-1])

# %%
data3=data3[["Source",'userId','screenName','name','friendsCount','followersCount']]

# %%
data3.dropna(inplace=True)

# %%
data3
# Out:
#              Source        userId       screenName  \
# 0          devanlli  1.366810e+18       joandiaz38
# 1     PuneetNigam11  1.323210e+18    radha16679092
# 2     PuneetNigam11  2.253841e+09   kevinbutani777
# 3     PuneetNigam11  1.243160e+18  40r15OxYJBRWB6n
# 4     PuneetNigam11  2.343897e+09     mishra_nawal
# ...             ...           ...              ...
# 4632  kamlamahendra  1.199000e+18  ManpowerConsul3
# 4633  kamlamahendra  7.757160e+17   IndiaAgreemind
# 4634  kamlamahendra  9.384040e+17     SureshP72318
# 4635  kamlamahendra  9.985280e+17       DALOORam14
# 4636  kamlamahendra  1.019400e+18  RamLalM11223395
#
#                                  name  friendsCount  followersCount
# 0                                Joan        4359.0          1001.0
# 1                               radha         143.0            53.0
# 2                         Kevin Patel         373.0           328.0
# 3                        Shubhi Gupta         115.0             6.0
# ...

# %%
new_data=data3.drop_duplicates(subset=['userId'])

# %%
len(data3['Source'].unique())
# Out:
# 77

# %%
new_data.drop(['Source'],axis=1,inplace=True)
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_21284\588211855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.drop(['Source'],axis=1,inplace=True)

# %%
Total_Nodes=pandas.concat([Nodes,new_data])

# %%
Total_Nodes
# Out:
#             userId       screenName                             name  \
# 0     1.605392e+18    ParvinKamble6                    Parvin Kamble
# 1     1.591976e+18         devanlli                 purnima devanlli
# 2     1.120174e+18    PuneetNigam11                     Puneet Nigam
# 3     1.590064e+18        palta_dr_              Anuradha palta ,PhD
# 4     8.092192e+17       KashniyalM                 Kashniyal Manish
# ...            ...              ...                              ...
# 4632  1.199000e+18  ManpowerConsul3  Fiveland Multi Services Pvt Ltd
# 4633  7.757160e+17   IndiaAgreemind       Kerala Agreemind matrimony
# 4634  9.384040e+17     SureshP72318                    सुरेश प्रजापत
# 4635  9.985280e+17       DALOORam14                        Daloo ram
# 4636  1.019400e+18  RamLalM11223395                    Ram Lal Meena
#
#       friendsCount  followersCount       Source
# 0              3.0             0.0  423190436.0
# ...

# %%
himalayadata=[{
    "userId":423190436,
    "screenName":"HimalayaIndia",
    "name":"Himalaya Wellness Company",
    "friendsCount":53,
    "followersCount":15719
}]

# %%
pandas.DataFrame(himalayadata)
# Out:
#       userId     screenName                       name  friendsCount  \
# 0  423190436  HimalayaIndia  Himalaya Wellness Company            53
#
#    followersCount
# 0           15719

# %%
Total_Nodes=pandas.concat([pandas.DataFrame(himalayadata),Total_Nodes])

# %%
Total_Nodes.drop_duplicates(subset=['userId'])
# Out:
#             userId       screenName                             name  \
# 0     4.231904e+08    HimalayaIndia        Himalaya Wellness Company
# 0     1.605392e+18    ParvinKamble6                    Parvin Kamble
# 1     1.591976e+18         devanlli                 purnima devanlli
# 2     1.120174e+18    PuneetNigam11                     Puneet Nigam
# 3     1.590064e+18        palta_dr_              Anuradha palta ,PhD
# ...            ...              ...                              ...
# 4632  1.199000e+18  ManpowerConsul3  Fiveland Multi Services Pvt Ltd
# 4633  7.757160e+17   IndiaAgreemind       Kerala Agreemind matrimony
# 4634  9.384040e+17     SureshP72318                    सुरेश प्रजापत
# 4635  9.985280e+17       DALOORam14                        Daloo ram
# 4636  1.019400e+18  RamLalM11223395                    Ram Lal Meena
#
#       friendsCount  followersCount       Source
# 0             53.0         15719.0          NaN
# ...

# %%
Total_Nodes=Total_Nodes[['userId','screenName','name','friendsCount','followersCount']]

# %%
Total_Nodes.columns=['Id','Label','name','friendsCount','followersCount']

# %%
Total_Nodes['Id']=Total_Nodes['Id'].apply(lambda x:float(x))
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_21284\4120943519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Total_Nodes['Id']=Total_Nodes['Id'].apply(lambda x:float(x))

# %%
Total_Nodes.to_csv("./Followers/Total_Nodes.csv",index=False)

# %%
Total_Nodes
# Out:
#                 Id            Label                             name  \
# 0     4.231904e+08    HimalayaIndia        Himalaya Wellness Company
# 0     1.605392e+18    ParvinKamble6                    Parvin Kamble
# 1     1.591976e+18         devanlli                 purnima devanlli
# 2     1.120174e+18    PuneetNigam11                     Puneet Nigam
# 3     1.590064e+18        palta_dr_              Anuradha palta ,PhD
# ...            ...              ...                              ...
# 4632  1.199000e+18  ManpowerConsul3  Fiveland Multi Services Pvt Ltd
# 4633  7.757160e+17   IndiaAgreemind       Kerala Agreemind matrimony
# 4634  9.384040e+17     SureshP72318                    सुरेश प्रजापत
# 4635  9.985280e+17       DALOORam14                        Daloo ram
# 4636  1.019400e+18  RamLalM11223395                    Ram Lal Meena
#
#       friendsCount  followersCount
# 0             53.0         15719.0
# 0              3.0             0.0
# ...

# %%
Nodes['Source']=423190436
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_21284\3927996735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nodes['Source']=423190436

# %%
Total_Edges=Nodes[['Source',"source_id"]]

# %%
Total_Edges.columns=['Source',"Target"]

# %%
Total_Edges['Type']="Directed"
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_21284\2225936721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Total_Edges['Type']="Directed"

# %%
Total_Edges
# Out:
#        Source               Target      Type
# 0   423190436  1605392339488210945  Directed
# 1   423190436  1591975778266189825  Directed
# 2   423190436  1120173746369646592  Directed
# 3   423190436  1590063878511419393  Directed
# 4   423190436   809219187386306560  Directed
# ..        ...                  ...       ...
# 95  423190436  1144086798844358656  Directed
# 96  423190436  1582624744444030977  Directed
# 97  423190436  1022740677757554689  Directed
# 98  423190436            771733183  Directed
# 99  423190436  1618279715587899393  Directed
#
# [100 rows x 3 columns]

# %%
Nodes.columns=['source_id', 'source_name', 'name', 'friendsCount', 'followersCount','Source']

# %%
Nodes
# Out:
#               source_id      source_name                    name  \
# 0   1605392339488210945    ParvinKamble6           Parvin Kamble
# 1   1591975778266189825         devanlli        purnima devanlli
# 2   1120173746369646592    PuneetNigam11            Puneet Nigam
# 3   1590063878511419393        palta_dr_     Anuradha palta ,PhD
# 4    809219187386306560       KashniyalM        Kashniyal Manish
# ..                  ...              ...                     ...
# 95  1144086798844358656  Shreyasgowda301         Shreyasgowda@30
# 96  1582624744444030977      diosleayuda                      さに
# 97  1022740677757554689    kamlamahendra  mahendra kumar bhaskar
# 98            771733183         Bertinrm                  Bertin
# 99  1618279715587899393       HenryTana3              Henry Tana
#
#     friendsCount  followersCount     Source
# 0              3               0  423190436
# 1             24               1  423190436
# 2             77               4  423190436
# ...

# %%
data3.rename({"source_id":"source_name"},inplace=True,axis=1)

# %%
data3
# Out:
#         source_name        userId       screenName  \
# 0          devanlli  1.366810e+18       joandiaz38
# 1     PuneetNigam11  1.323210e+18    radha16679092
# 2     PuneetNigam11  2.253841e+09   kevinbutani777
# 3     PuneetNigam11  1.243160e+18  40r15OxYJBRWB6n
# 4     PuneetNigam11  2.343897e+09     mishra_nawal
# ...             ...           ...              ...
# 4632  kamlamahendra  1.199000e+18  ManpowerConsul3
# 4633  kamlamahendra  7.757160e+17   IndiaAgreemind
# 4634  kamlamahendra  9.384040e+17     SureshP72318
# 4635  kamlamahendra  9.985280e+17       DALOORam14
# 4636  kamlamahendra  1.019400e+18  RamLalM11223395
#
#                                  name  friendsCount  followersCount
# 0                                Joan        4359.0          1001.0
# 1                               radha         143.0            53.0
# 2                         Kevin Patel         373.0           328.0
# 3                        Shubhi Gupta         115.0             6.0
# ...

# %%
temp=data3.merge(Nodes[['source_name','source_id']],on="source_name")

# %%
temp
# Out:
#         source_name        userId       screenName  \
# 0          devanlli  1.366810e+18       joandiaz38
# 1     PuneetNigam11  1.323210e+18    radha16679092
# 2     PuneetNigam11  2.253841e+09   kevinbutani777
# 3     PuneetNigam11  1.243160e+18  40r15OxYJBRWB6n
# 4     PuneetNigam11  2.343897e+09     mishra_nawal
# ...             ...           ...              ...
# 4608  kamlamahendra  1.199000e+18  ManpowerConsul3
# 4609  kamlamahendra  7.757160e+17   IndiaAgreemind
# 4610  kamlamahendra  9.384040e+17     SureshP72318
# 4611  kamlamahendra  9.985280e+17       DALOORam14
# 4612  kamlamahendra  1.019400e+18  RamLalM11223395
#
#                                  name  friendsCount  followersCount  \
# 0                                Joan        4359.0          1001.0
# 1                               radha         143.0            53.0
# 2                         Kevin Patel         373.0           328.0
# 3                        Shubhi Gupta         115.0             6.0
# ...

# %%
temp=temp[['source_id',"userId"]]

# %%
temp.columns=['Source',"Target"]

# %%
temp['Type']="Directed"
# Out:
# C:\Users\Pankaj singh\AppData\Local\Temp\ipykernel_21284\3564052516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Type']="Directed"

# %%
temp
# Out:
#                    Source        Target      Type
# 0     1591975778266189825  1.366810e+18  Directed
# 1     1120173746369646592  1.323210e+18  Directed
# 2     1120173746369646592  2.253841e+09  Directed
# 3     1120173746369646592  1.243160e+18  Directed
# 4     1120173746369646592  2.343897e+09  Directed
# ...                   ...           ...       ...
# 4608  1022740677757554689  1.199000e+18  Directed
# 4609  1022740677757554689  7.757160e+17  Directed
# 4610  1022740677757554689  9.384040e+17  Directed
# 4611  1022740677757554689  9.985280e+17  Directed
# 4612  1022740677757554689  1.019400e+18  Directed
#
# [4613 rows x 3 columns]

# %%
Total_Edges=pandas.concat([Total_Edges,temp])

# %%
Total_Edges.to_csv("./Followers/Total_Edges.csv",index=False)

# %%
Total_Edges
# Out:
#                    Source        Target      Type
# 0               423190436  1.605392e+18  Directed
# 1               423190436  1.591976e+18  Directed
# 2               423190436  1.120174e+18  Directed
# 3               423190436  1.590064e+18  Directed
# 4               423190436  8.092192e+17  Directed
# ...                   ...           ...       ...
# 4608  1022740677757554689  1.199000e+18  Directed
# 4609  1022740677757554689  7.757160e+17  Directed
# 4610  1022740677757554689  9.384040e+17  Directed
# 4611  1022740677757554689  9.985280e+17  Directed
# 4612  1022740677757554689  1.019400e+18  Directed
#
# [4713 rows x 3 columns]

# %%
len(data3['screenName'].unique())
# Out:
# 4577
