# %%
import pandas
import numpy
import matplotlib.pyplot as pyplot

# %%
Data= pandas.read_csv("../Data/Raw_Data/Twitter_Data/Twitter_Search_Data_for_Experiment-7.csv")

# %%
Data
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
# 5  snscrape.modules.twitter.Tweet
# 6  snscrape.modules.twitter.Tweet
# 7  snscrape.modules.twitter.Tweet
# 8  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/IamRayin/status/1627897816...
# 1  https://twitter.com/rebelioushamila/status/162...
# 2  https://twitter.com/Its_Mangesh99/status/16266...
# 3  https://twitter.com/AherAlok/status/1620681654...
# 4  https://twitter.com/PChandr43659403/status/162...
# 5  https://twitter.com/sereneloud/status/16206548...
# 6  https://twitter.com/sereneloud/status/16206499...
# 7  https://twitter.com/MrAnkit26599/status/162064...
# 8  https://twitter.com/SmartyPantBot/status/16203...
#
#                         date  \
# 0  2023-02-21 05:07:39+00:00
# ...

# %%
Data.columns
# Out:
# Index(['_type', 'url', 'date', 'rawContent', 'renderedContent', 'id', 'user',
#        'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel', 'links',
#        'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#        'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#        'cashtags', 'card', 'viewCount', 'vibe', 'content', 'outlinks',
#        'outlinksss', 'tcooutlinks', 'tcooutlinksss', 'username'],
#       dtype='object')

# %%
Data = Data[[ 'date', 'rawContent' , 'renderedContent' , 'user' , 'replyCount' ,'retweetCount' , 'likeCount' , 'lang' , 'place' , 'hashtags' , 'viewCount']]

# %%
Data['place']
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5    {'_type': 'snscrape.modules.twitter.Place', 'i...
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# Name: place, dtype: object

# %%
Data.user[0]
# Out:
# "{'_type': 'snscrape.modules.twitter.User', 'username': 'IamRayin', 'id': 1237345071672016899, 'displayname': 'Rayin', 'rawDescription': 'Keralite, male, married, father of 2 kids.\\nMechanical Engineer.', 'renderedDescription': 'Keralite, male, married, father of 2 kids.\\nMechanical Engineer.', 'descriptionLinks': None, 'verified': False, 'created': '2020-03-10T11:50:40+00:00', 'followersCount': 377, 'friendsCount': 1099, 'statusesCount': 13268, 'favouritesCount': 37868, 'listedCount': 1, 'mediaCount': 497, 'location': '', 'protected': False, 'link': None, 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1619949326117081091/Gj_J5oYm_normal.jpg', 'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/1237345071672016899/1586147103', 'label': None, 'description': 'Keralite, male, married, father of 2 kids.\\nMechanical Engineer.', 'descriptionUrls': None, 'linkTcourl': None, 'linkUrl': None, 'url': 'https://twitter.com/IamRayin'}"
